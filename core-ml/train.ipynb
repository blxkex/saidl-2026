# %%
# !git clone https://github.com/blxkex/saidl-2026.git
# Out:
# Cloning into 'saidl-2026'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 84 (delta 39), reused 70 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 1.20 MiB | 4.50 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd saidl-2026
# Out:
# /content/saidl-2026

# %%
# !uv sync
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 78 packages in 16ms
# Prepared 75 packages in 52.73s
# Installed 75 packages in 597ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.13.0
#  + attrs==26.1.0
#  + certifi==2026.2.25
#  + charset-normalizer==3.4.6
#  + click==8.3.1
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.0
#  + cuda-toolkit==13.0.2
#  + datasets==4.8.4
#  + dill==0.4.1
#  + filelock==3.25.2
#  + frozenlist==1.8.0
#  + fsspec==2026.2.0
#  + h11==0.16.0
#  + hf-xet==1.4.2
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.8.0
#  + hydra-core==1.3.2
#  + idna==3.11
#  + jinja2==3.1.6
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + mdurl==0.1.2
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + multiprocess==0.70.19
#  + networkx==3.6.1
#  + numpy==2.4.3
#  + nvidia-cublas==13.1.0.3
# ...

# %%
# !uv add wandb
# Out:
# Resolved 89 packages in 861ms
# Prepared 11 packages in 789ms                                            ⠋ Preparing packages... (0/0)
# Installed 11 packages in 30ms
#  + annotated-types==0.7.0
#  + gitdb==4.0.12
#  + gitpython==3.1.50
#  + platformdirs==4.10.0
#  + protobuf==7.35.0
#  + pydantic==2.13.4
#  + pydantic-core==2.46.4
#  + sentry-sdk==2.60.0
#  + smmap==5.0.3
#  + typing-inspection==0.4.2
#  + wandb==0.27.0

# %%
# !wandb login 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
# Out:
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
